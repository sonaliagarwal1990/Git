# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv("Book2.csv")
df1
# Out:
#   OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0    9/1/14  Central    Smith    Desk      2     125.00  250.00
# 1   6/17/15  Central   Kivell    Desk      5     125.00  625.00
# 2   9/10/15  Central     Gill  Pencil      7       1.29    9.03
# 3  11/17/15  Central  Jardine  Binder     11       4.99   54.89
# 4  10/31/15  Central  Andrews  Pencil     14       1.29   18.06
# 5   2/26/14  Central     Gill     Pen     27      19.99  539.73
# 6   10/5/14  Central   Morgan  Binder     28       8.99  251.72
# 7  12/21/15  Central  Andrews  Binder     28       4.99  139.72

# %%
new_df = df1.replace(4.99,np.NaN)
new_df
# Out:
#   OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0    9/1/14  Central    Smith    Desk      2     125.00  250.00
# 1   6/17/15  Central   Kivell    Desk      5     125.00  625.00
# 2   9/10/15  Central     Gill  Pencil      7       1.29    9.03
# 3  11/17/15  Central  Jardine  Binder     11        NaN   54.89
# 4  10/31/15  Central  Andrews  Pencil     14       1.29   18.06
# 5   2/26/14  Central     Gill     Pen     27      19.99  539.73
# 6   10/5/14  Central   Morgan  Binder     28       8.99  251.72
# 7  12/21/15  Central  Andrews  Binder     28        NaN  139.72

# %%
new_df= df1.replace({'Item':'[A-Za-z]','Region':'[A-Za-z]'},'',regex=True)

# %%
new_df
# Out:
#   OrderDate Region      Rep Item  Units  Unit Cost   Total
# 0    9/1/14           Smith           2     125.00  250.00
# 1   6/17/15          Kivell           5     125.00  625.00
# 2   9/10/15            Gill           7       1.29    9.03
# 3  11/17/15         Jardine          11       4.99   54.89
# 4  10/31/15         Andrews          14       1.29   18.06
# 5   2/26/14            Gill          27      19.99  539.73
# 6   10/5/14          Morgan          28       8.99  251.72
# 7  12/21/15         Andrews          28       4.99  139.72

# %%
type(df1.Rep[0])
# Out:
# str

# %%
df = pd.DataFrame({
    'score':['exceptional','average','good','poor','average','exceptional'],
    'student':['rob','maya','parthiv','tom', 'julian','erica']
})
df
# Out:
#          score  student
# 0  exceptional      rob
# 1      average     maya
# 2         good  parthiv
# 3         poor      tom
# 4      average   julian
# 5  exceptional    erica

# %%
new_df=df.replace(['poor','average','good','exceptional'],[1,2,3,4])
new_df
# Out:
#    score  student
# 0      4      rob
# 1      2     maya
# 2      3  parthiv
# 3      1      tom
# 4      2   julian
# 5      4    erica

# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv("Book3.csv")
df1
# Out:
#          day      city  temperture  windspeed   event
# 0   1/1/2017  new york          25          1    rain
# 1   1/1/2017  new york          36         12   sunny
# 2   1/1/2017  new york          25          4    snow
# 3   1/1/2017  new york          48          5   sunny
# 4   1/1/2017    mumbai          49          8   sunny
# 5   1/1/2017    mumbai          75          7     fog
# 6   1/1/2017    mumbai          98          5     fog
# 7   1/1/2017    mumbai          99          3    rain
# 8   1/1/2017    mumbai          75          4  cloudy
# 9   1/1/2017     paris          12          6  cloudy
# 10  1/1/2017     paris          34          7  cloudy
# 11  1/1/2017     paris          33          8   sunny

# %%
g=df1.groupby('city')
g

# %%
for city,city_df in g:
    print(city)
    print(city_df)
# Out:
# mumbai
#         day    city  temperture  windspeed   event
# 4  1/1/2017  mumbai          49          8   sunny
# 5  1/1/2017  mumbai          75          7     fog
# 6  1/1/2017  mumbai          98          5     fog
# 7  1/1/2017  mumbai          99          3    rain
# 8  1/1/2017  mumbai          75          4  cloudy
# new york
#         day      city  temperture  windspeed  event
# 0  1/1/2017  new york          25          1   rain
# 1  1/1/2017  new york          36         12  sunny
# 2  1/1/2017  new york          25          4   snow
# 3  1/1/2017  new york          48          5  sunny
# paris
#          day   city  temperture  windspeed   event
# 9   1/1/2017  paris          12          6  cloudy
# 10  1/1/2017  paris          34          7  cloudy
# 11  1/1/2017  paris          33          8   sunny

# %%
g.get_group('mumbai')
# Out:
#         day    city  temperture  windspeed   event
# 4  1/1/2017  mumbai          49          8   sunny
# 5  1/1/2017  mumbai          75          7     fog
# 6  1/1/2017  mumbai          98          5     fog
# 7  1/1/2017  mumbai          99          3    rain
# 8  1/1/2017  mumbai          75          4  cloudy

# %%
SELECT * from city_data Group By city
# Out:
#   File "<ipython-input-28-3e0478b7bec0>", line 1
#     SELECT * from city_data Group By city
#                 ^
# SyntaxError: invalid syntax

# %%
g.max()
# Out:
#                day  temperture  windspeed  event
# city
# mumbai    1/1/2017          99          8  sunny
# new york  1/1/2017          48         12  sunny
# paris     1/1/2017          34          8  sunny

# %%
# %matlotlib inline
g.plot()
# Out:
# UsageError: Line magic function `%matlotlib` not found.

# %%
ipython notebook --pylab=inline
# Out:
#   File "<ipython-input-31-19e39bcd4ac9>", line 1
#     ipython notebook --pylab=inline
#                    ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# mumbai      AxesSubplot(0.125,0.125;0.775x0.755)
# new york    AxesSubplot(0.125,0.125;0.775x0.755)
# paris       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
india_weather = pd.DataFrame({ "city":["mumbai","delhi","banglore"],
                "temperature" : [32,45,30],
                "humidity" : [80,60,78]})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather = pd.DataFrame({"city":["new York","chicago","orlando"],
                          "temperature":[21,14,75],
                          "humidity":[80,65,75]})
us_weather
# Out:
#        city  temperature  humidity
# 0  new York           21        80
# 1   chicago           14        65
# 2   orlando           75        75

# %%
df = pd.concat([india_weather,us_weather])
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 0  new York           21        80
# 1   chicago           14        65
# 2   orlando           75        75

# %%
df = pd.concat([india_weather,us_weather],ignore_index=True)
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new York           21        80
# 4   chicago           14        65
# 5   orlando           75        75

# %%
df = pd.concat([india_weather,us_weather],keys=["india","us"])
df
# Out:
#              city  temperature  humidity
# india 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# us    0  new York           21        80
#       1   chicago           14        65
#       2   orlando           75        75

# %%
df.loc["us"]
# Out:
#        city  temperature  humidity
# 0  new York           21        80
# 1   chicago           14        65
# 2   orlando           75        75

# %%
temperature_df =pd.DataFrame( {
    "city" : ["mumbai","delhi","banglore"],
    "temperature":[32,45,30],
})
temperature_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
windspeed_df = pd.DataFrame({  "city" : ["mumbai","delhi"],
    "windspeed":[7,12,9],})
windspeed_df
# Out:
#        city  windspeed
# 0    mumbai          7
# 1     delhi         12
# 2  banglore          9

# %%
df= pd.concat([temperature_df,windspeed_df],axis=1)
df
# Out:
#        city  temperature      city  windspeed
# 0    mumbai           32    mumbai          7
# 1     delhi           45     delhi         12
# 2  banglore           30  banglore          9

# %%
df1=pd.melt(windspeed_df, id_vars=["city"])

# %%
df1
# Out:
#        city   variable  value
# 0    mumbai  windspeed      7
# 1     delhi  windspeed     12
# 2  banglore  windspeed      9

# %%
import pandas as pd

# %%
type(df.date[0])
# Out:
# str

# %%
df.index
# Out:
# RangeIndex(start=0, stop=62, step=1)

# %%
df["2019-02-15":"2019-04-30"]
# Out:
# Empty DataFrame
# Columns: [close, volume, open, high, low]
# Index: []

# %%
df.close.resample('Q').mean().plotkind=("bar")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-458b82192408> in <module>
# ----> 1 df.close.resample('Q').mean().plotkind=("bar")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    8153                      axis=axis, kind=kind, loffset=loffset,
#    8154                      convention=convention,
# -> 8155                      base=base, key=on, level=level)
#    8156         return _maybe_process_deprecations(r,
#    8157                                            how=how,
#
# ~\Anaconda3\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#    1248     """
#    1249     tg = TimeGrouper(**kwds)
# -> 1250     return tg._get_resampler(obj, kind=kind)
#    1251
#    1252
#
# ...

# %%
df
# Out:
#              close    volume    open      high       low
# date
# 2019-05-08  202.90  26339500  202.86  205.3400  201.7500
# 2019-05-07  202.86  38763700  208.48  207.4180  200.8250
# 2019-05-06  208.48  32443110  211.75  208.8400  203.5000
# 2019-05-03  211.75  20892380  209.15  211.8400  210.2300
# 2019-05-02  209.15  31996320  210.52  212.6500  208.1300
# 2019-05-01  210.52  64827330  200.67  215.3100  209.2300
# 2019-04-30  200.67  45751160  203.06  203.4000  199.1100
# 2019-04-29  204.61  22010360  204.40  205.9700  203.8600
# 2019-04-26  204.30  18612770  204.90  205.0000  202.1200
# 2019-04-25  205.28  18463850  206.83  207.7600  205.1200
# 2019-04-24  207.16  17427570  207.36  208.4800  207.0500
# 2019-04-23  207.48  23286380  204.43  207.7500  203.9000
# 2019-04-22  204.53  17841920  202.83  204.9400  202.3400
# 2019-04-18  203.86  24185530  203.12  204.1500  202.5200
# 2019-04-17  203.13  28865310  199.54  203.3800  198.6100
# ...

# %%
rng = pd.date_range(start = "2/8/2019",end="5/8/2019",freq='B')
rng
# Out:
# DatetimeIndex(['2019-02-08', '2019-02-11', '2019-02-12', '2019-02-13',
#                '2019-02-14', '2019-02-15', '2019-02-18', '2019-02-19',
#                '2019-02-20', '2019-02-21', '2019-02-22', '2019-02-25',
#                '2019-02-26', '2019-02-27', '2019-02-28', '2019-03-01',
#                '2019-03-04', '2019-03-05', '2019-03-06', '2019-03-07',
#                '2019-03-08', '2019-03-11', '2019-03-12', '2019-03-13',
#                '2019-03-14', '2019-03-15', '2019-03-18', '2019-03-19',
#                '2019-03-20', '2019-03-21', '2019-03-22', '2019-03-25',
#                '2019-03-26', '2019-03-27', '2019-03-28', '2019-03-29',
#                '2019-04-01', '2019-04-02', '2019-04-03', '2019-04-04',
#                '2019-04-05', '2019-04-08', '2019-04-09', '2019-04-10',
#                '2019-04-11', '2019-04-12', '2019-04-15', '2019-04-16',
#                '2019-04-17', '2019-04-18', '2019-04-19', '2019-04-22',
# ...

# %%
df.set_index(rng,inplace=True)
df
# Out:
#              close    volume    open      high       low
# 2019-02-08  202.90  26339500  202.86  205.3400  201.7500
# 2019-02-11  202.86  38763700  208.48  207.4180  200.8250
# 2019-02-12  208.48  32443110  211.75  208.8400  203.5000
# 2019-02-13  211.75  20892380  209.15  211.8400  210.2300
# 2019-02-14  209.15  31996320  210.52  212.6500  208.1300
# 2019-02-15  210.52  64827330  200.67  215.3100  209.2300
# 2019-02-18  200.67  45751160  203.06  203.4000  199.1100
# 2019-02-19  204.61  22010360  204.40  205.9700  203.8600
# 2019-02-20  204.30  18612770  204.90  205.0000  202.1200
# 2019-02-21  205.28  18463850  206.83  207.7600  205.1200
# 2019-02-22  207.16  17427570  207.36  208.4800  207.0500
# 2019-02-25  207.48  23286380  204.43  207.7500  203.9000
# 2019-02-26  204.53  17841920  202.83  204.9400  202.3400
# 2019-02-27  203.86  24185530  203.12  204.1500  202.5200
# 2019-02-28  203.13  28865310  199.54  203.3800  198.6100
# ...

# %%
# %matplotlib inline
df.close.plot()

# %%
df["2019-04-12":"2019-05-08"].close.mean()
# Out:
# 171.1273684210526

# %%
df.asfreq('D',method="pad")
# Out:
#              close    volume    open      high       low
# 2019-02-08  202.90  26339500  202.86  205.3400  201.7500
# 2019-02-09  202.90  26339500  202.86  205.3400  201.7500
# 2019-02-10  202.90  26339500  202.86  205.3400  201.7500
# 2019-02-11  202.86  38763700  208.48  207.4180  200.8250
# 2019-02-12  208.48  32443110  211.75  208.8400  203.5000
# 2019-02-13  211.75  20892380  209.15  211.8400  210.2300
# 2019-02-14  209.15  31996320  210.52  212.6500  208.1300
# 2019-02-15  210.52  64827330  200.67  215.3100  209.2300
# 2019-02-16  210.52  64827330  200.67  215.3100  209.2300
# 2019-02-17  210.52  64827330  200.67  215.3100  209.2300
# 2019-02-18  200.67  45751160  203.06  203.4000  199.1100
# 2019-02-19  204.61  22010360  204.40  205.9700  203.8600
# 2019-02-20  204.30  18612770  204.90  205.0000  202.1200
# 2019-02-21  205.28  18463850  206.83  207.7600  205.1200
# 2019-02-22  207.16  17427570  207.36  208.4800  207.0500
# ...

# %%
import numpy as np
ts = pd.series(np.random.randint(1,10,len(rng)),index=rng)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-117-d5e0a0be3361> in <module>
#       1 import numpy as np
# ----> 2 ts = pd.series(np.random.randint(1,10,len(rng)),index=rng)
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
import pandas as pd
dates = ['2017-01-05 2:30:00 PM','Jan 5, 2017 14:30:00','01/05/2017','2017.01.05','2017/01/05','20170105']

pd.to_datetime(dates)
# Out:
# DatetimeIndex(['2017-01-05 14:30:00', '2017-01-05 14:30:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime('5$1$2017',format='%d$%m$%Y')
# Out:
# Timestamp('2017-01-05 00:00:00')

# %%
dates = ['2017-01-05 2:30:00 PM','Jan 5, 2017 14:30:00','01/05/2017','2017.01.05','2017/01/05','20170105','abc']

pd.to_datetime(dates,errors='ignore')
# Out:
# Index(['2017-01-05 2:30:00 PM', 'Jan 5, 2017 14:30:00', '01/05/2017',
#        '2017.01.05', '2017/01/05', '20170105', 'abc'],
#       dtype='object')

# %%
dates = ['2017-01-05 2:30:00 PM','Jan 5, 2017 14:30:00','01/05/2017','2017.01.05','2017/01/05','20170105','abc']

pd.to_datetime(dates,errors='coerce')
# Out:
# DatetimeIndex(['2017-01-05 14:30:00', '2017-01-05 14:30:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00',
#                                'NaT'],
#               dtype='datetime64[ns]', freq=None)

# %%
t= 1501356749
dt = pd.to_datetime([t], unit='s')

# %%
dt.view('int64')
# Out:
# array([1501356749000000000], dtype=int64)

# %%
y=pd.Period('2016')
y
# Out:
# Period('2016', 'A-DEC')

# %%
dir(y)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_add_delta',
#  '_from_ordinal',
#  '_maybe_convert_freq',
#  '_typ',
#  'asfreq',
#  'day',
#  'dayofweek',
#  'dayofyear',
#  'days_in_month',
#  'daysinmonth',
#  'end_time',
#  'freq',
#  'freqstr',
#  'hour',
#  'is_leap_year',
#  'minute',
#  'month',
#  'now',
#  'ordinal',
#  'quarter',
#  'qyear',
#  'second',
#  'start_time',
#  'strftime',
#  'to_timestamp',
#  'week',
#  'weekday',
#  'weekofyear',
#  'year']

# %%
y.start_time
# Out:
# Timestamp('2016-01-01 00:00:00')

# %%
import pandas as pd
df   = pd.read_csv("HistoricalQuotes.csv",index_col = 'date',parse_dates=True)
df
# Out:
#             close
# date
# 2017-08-28  72.83
# 2017-08-25  72.82
# 2017-08-24  72.69
# 2017-08-23  72.72
# 2017-08-22  73.16
# 2017-08-21  72.15
# 2017-08-18  72.49
# 2017-08-17  72.40
# 2017-08-16  73.65

# %%
df.index
# Out:
# DatetimeIndex(['2017-08-28', '2017-08-25', '2017-08-24', '2017-08-23',
#                '2017-08-22', '2017-08-21', '2017-08-18', '2017-08-17',
#                '2017-08-16'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
df=df.tz_localize(tz='US/Eastern')
df.index
# Out:
# DatetimeIndex(['2017-08-28 00:00:00-04:00', '2017-08-25 00:00:00-04:00',
#                '2017-08-24 00:00:00-04:00', '2017-08-23 00:00:00-04:00',
#                '2017-08-22 00:00:00-04:00', '2017-08-21 00:00:00-04:00',
#                '2017-08-18 00:00:00-04:00', '2017-08-17 00:00:00-04:00',
#                '2017-08-16 00:00:00-04:00'],
#               dtype='datetime64[ns, US/Eastern]', name='date', freq=None)

# %%
df = df.tz_convert(tz='Europe/Berlin')
df
# Out:
#                            close
# date
# 2017-08-28 06:00:00+02:00  72.83
# 2017-08-25 06:00:00+02:00  72.82
# 2017-08-24 06:00:00+02:00  72.69
# 2017-08-23 06:00:00+02:00  72.72
# 2017-08-22 06:00:00+02:00  73.16
# 2017-08-21 06:00:00+02:00  72.15
# 2017-08-18 06:00:00+02:00  72.49
# 2017-08-17 06:00:00+02:00  72.40
# 2017-08-16 06:00:00+02:00  73.65

# %%
from pytz import all_timezones
all_timezones
# Out:
# ['Africa/Abidjan',
#  'Africa/Accra',
#  'Africa/Addis_Ababa',
#  'Africa/Algiers',
#  'Africa/Asmara',
#  'Africa/Asmera',
#  'Africa/Bamako',
#  'Africa/Bangui',
#  'Africa/Banjul',
#  'Africa/Bissau',
#  'Africa/Blantyre',
#  'Africa/Brazzaville',
#  'Africa/Bujumbura',
#  'Africa/Cairo',
#  'Africa/Casablanca',
#  'Africa/Ceuta',
#  'Africa/Conakry',
#  'Africa/Dakar',
#  'Africa/Dar_es_Salaam',
#  'Africa/Djibouti',
#  'Africa/Douala',
#  'Africa/El_Aaiun',
#  'Africa/Freetown',
#  'Africa/Gaborone',
#  'Africa/Harare',
#  'Africa/Johannesburg',
#  'Africa/Juba',
#  'Africa/Kampala',
#  'Africa/Khartoum',
#  'Africa/Kigali',
#  'Africa/Kinshasa',
#  'Africa/Lagos',
#  'Africa/Libreville',
#  'Africa/Lome',
#  'Africa/Luanda',
#  'Africa/Lubumbashi',
#  'Africa/Lusaka',
#  'Africa/Malabo',
#  'Africa/Maputo',
#  'Africa/Maseru',
#  'Africa/Mbabane',
#  'Africa/Mogadishu',
#  'Africa/Monrovia',
#  'Africa/Nairobi',
#  'Africa/Ndjamena',
#  'Africa/Niamey',
#  'Africa/Nouakchott',
# ...

# %%
import pandas as pd

# %%
import sqlalchemy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-149-eedda4fafed5> in <module>
#       1 import sqlalchemy
# ----> 2 import pymysql
#
# ModuleNotFoundError: No module named 'pymysql'

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:@localhost:3306/application')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-148-64c7dd8c8d91> in <module>
# ----> 1 engine = sqlalchemy.create_engine('mysql+pymysql://root:@localhost:3306/application')
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\__init__.py in create_engine(*args, **kwargs)
#     421     strategy = kwargs.pop("strategy", default_strategy)
#     422     strategy = strategies.strategies[strategy]
# --> 423     return strategy.create(*args, **kwargs)
#     424
#     425
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in create(self, name_or_url, **kwargs)
#      85                 if k in kwargs:
#      86                     dbapi_args[k] = pop_kwarg(k)
# ---> 87             dbapi = dialect_cls.dbapi(**dbapi_args)
#      88
#      89         dialect_args["dbapi"] = dbapi
#
# ...
